# %%
from pathlib import Path
from markitdown import MarkItDown

document_name = "Chen et al. - 2010 - Can Exchange Rates Forecast Commodity Prices"

# Input PDF
pdf_path = Path("pdf") / f"{document_name}.pdf"

# Output Markdown file
md_path = Path("md") / f"{document_name}.md"

# Convert
md = MarkItDown(enable_plugins=False)
result = md.convert(str(pdf_path))

# Save as Markdown
md_path.write_text(result.text_content, encoding="utf-8")

print(f"Saved to: {md_path}")
# Out:
# Saved to: md\Chen et al. - 2010 - Can Exchange Rates Forecast Commodity Prices.md
