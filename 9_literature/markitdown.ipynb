# %%
from pathlib import Path
from markitdown import MarkItDown

document_name = "main (8)"

# Input PDF
pdf_path = Path("pdf") / f"{document_name}.pdf"

# Output Markdown file
md_path = Path("md") / f"{document_name}.md"

# Convert
md = MarkItDown(enable_plugins=False)
result = md.convert(str(pdf_path))

# Save as Markdown
md_path.write_text(result.text_content, encoding="utf-8")

print(f"Saved to: {md_path}")
# Out:
# c:\Users\Leo\anaconda3\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# Saved to: md\main (8).md
