# %% [markdown]
# # Scratchpad Notebook

# %%
import sys
sys.path.append("..")
import pyperclip
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pathlib import Path

# %% [markdown]
# ### Turn Pandas Dataframe to Latex Table

# %%
from src.visualization.dataframe_to_latex import dataframe_to_latex

# %%
df = pd.DataFrame({
                   
    "Model": ["OLS", "LASSO", "Elastic Net"],
    "RMSE": [0.4213, 0.3874, 0.3721],
    "R2": [0.12, 0.18, 0.21]
})

# %%
pyperclip.copy(dataframe_to_latex(df, caption="Model comparison", label="model_comparison"))
df
# Out:
#          Model    RMSE    R2
# 0          OLS  0.4213  0.12
# 1        LASSO  0.3874  0.18
# 2  Elastic Net  0.3721  0.21

# %% [markdown]
# ### Create and Save Plots with CMU Serif or Helvetica Font

# %% [markdown]
#  CMU Serif

# %%
font_folder = Path(r"C:\USERS\LEO\APPDATA\LOCAL\MICROSOFT\WINDOWS\FONTS")

for font_file in [
    "CMUNRM.TTF",  # Roman
    "CMUNTI.TTF",  # Italic
    "CMUNBX.TTF",  # Bold
    "CMUNBI.TTF",  # Bold Italic
]:
    fm.fontManager.addfont(str(font_folder / font_file))

plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["CMU Serif"],

    "mathtext.fontset": "cm",

    "axes.unicode_minus": False,
})

# %% [markdown]
# Helvetica

# %%
font_folder = Path(r"C:\USERS\LEO\APPDATA\LOCAL\MICROSOFT\WINDOWS\FONTS")

for font_file in font_folder.glob("HELVETICA*.TTF"):
    fm.fontManager.addfont(str(font_file))

plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"],

    "mathtext.fontset": "custom",
    "mathtext.rm": "Helvetica",
    "mathtext.it": "Helvetica:italic",
    "mathtext.bf": "Helvetica:bold",

    "axes.unicode_minus": False,
})

# %%
plt.rcParams.update({
    "font.size": 9,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,

    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

# %%
x = np.linspace(-10, 10, 200)

cm = 1 / 2.54

fig, ax = plt.subplots(figsize=(7.5 * cm, 5 * cm))

ax.plot(x, np.log(x), color="black", label=r"$\log(x)$")
#ax.set_xlabel(r"Time")
#ax.set_ylabel(r"Units")
ax.grid(False)
ax.legend(frameon=False)
ax.tick_params(direction="inout")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.plot(1, 0, marker=">", transform=ax.transAxes, clip_on=False,
        color=ax.spines["bottom"].get_edgecolor(), markersize=5)

ax.plot(0, 1, marker="^", transform=ax.transAxes, clip_on=False,
        color=ax.spines["left"].get_edgecolor(), markersize=5)

ax.fill_between(
    x, y, 0,
    alpha=0.2,
    label=r"$\int \log(x)\,dx$"
)

fig.savefig("../1_latex/1.5_figures/test figures/my_plot.pdf", bbox_inches="tight", pad_inches=0.01)
plt.show()
# Out:
# C:\Users\Leo\AppData\Local\Temp\ipykernel_18552\1639623009.py:7: RuntimeWarning: invalid value encountered in log
#   ax.plot(x, np.log(x), color="black", label=r"$\log(x)$")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 22
#      15 ax.plot(1, 0, marker=">", transform=ax.transAxes, clip_on=False,
#      16         color=ax.spines["bottom"].get_edgecolor(), markersize=5)
#      18 ax.plot(0, 1, marker="^", transform=ax.transAxes, clip_on=False,
#      19         color=ax.spines["left"].get_edgecolor(), markersize=5)
#      21 ax.fill_between(
# ---> 22     x, y, 0,
#      23     alpha=0.2,
#      24     label=r"$\int \log(x)\,dx$"
#      25 )
#      27 fig.savefig("../1_latex/1.5_figures/test figures/my_plot.pdf", bbox_inches="tight", pad_inches=0.01)
#      28 plt.show()
#
# NameError: name 'y' is not defined

# %%
x = np.linspace(0.1, 10, 200)
y = np.log(x)

cm = 1 / 2.54

fig, ax = plt.subplots(figsize=(7.8 * cm, 4.5 * cm), layout="constrained")

ax.plot(x, y, color="green", label=r"$\log(x)$")
ax.fill_between(x, y, 0, color="green", alpha=0.1)

ax.set_xlabel(r"Time")
#ax.set_ylabel(r"Units")
ax.legend(frameon=False)
ax.grid(False)

# Put axes through zero
ax.spines["left"].set_position(("data", 0))    # y-axis at x = 0
ax.spines["bottom"].set_position(("data", 0))  # x-axis at y = 0

# Remove top/right borders
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Keep ticks on the moved axes
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

# Make sure x = 0 is visible
ax.set_xlim(0, 10)

fig.savefig(
    "../1_latex/1.5_figures/test figures/my_plot.pdf"
)

plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
x = np.linspace(0.1, 10, 200)
y = x**2

cm = 1 / 2.54

fig, ax = plt.subplots(figsize=(7.8 * cm, 4.5 * cm), layout="constrained")

ax.plot(x, y, color="orange", label=r"$x^2$")
ax.fill_between(x, y, 0, color="orange", alpha=0.1)

ax.set_xlabel(r"Time")
#ax.set_ylabel(r"Units")
ax.legend(frameon=False)
ax.grid(False)

# Put axes through zero
ax.spines["left"].set_position(("data", 0))    # y-axis at x = 0
ax.spines["bottom"].set_position(("data", 0))  # x-axis at y = 0

# Remove top/right borders
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Keep ticks on the moved axes
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

# Make sure x = 0 is visible
ax.set_xlim(0, 10)

fig.savefig(
    "../1_latex/1.5_figures/test figures/my_plot2.pdf"
)

plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
x = np.linspace(0.1, 10, 200)
y = np.log(x)

cm = 1 / 2.54

fig, ax = plt.subplots(figsize=(16 * cm, 7 * cm), layout="constrained")

ax.plot(x, y, color="green", label=r"$\log(x)$")
ax.fill_between(x, y, 0, color="green", alpha=0.1)

ax.set_xlabel(r"Time")
#ax.set_ylabel(r"Units")
ax.legend(frameon=False)
ax.grid(False)

# Put axes through zero
ax.spines["left"].set_position(("data", 0))    # y-axis at x = 0
ax.spines["bottom"].set_position(("data", 0))  # x-axis at y = 0

# Remove top/right borders
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Keep ticks on the moved axes
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

# Make sure x = 0 is visible
ax.set_xlim(0, 10)

fig.savefig(
    "../1_latex/1.5_figures/test figures/my_plot_long.pdf"
)

plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
